# %%
# %matplotlib inline
import numpy as np
import nibabel as nib
from nilearn import plotting
import SimpleITK as sitk

# %%
filename = 'case_001_2.nii.gz'
img = nib.load(filename)
data = img.get_data().swapaxes(0,2)
img2 = sitk.ReadImage('snapitk.nii.gz')
data2 = sitk.GetArrayFromImage(img2)

# %%
test = np.flipud(data)
test.shape
# Out:
# (33, 320, 288)

# %%
img.affine
# Out:
# array([[ -6.24766290e-01,   6.14132495e-11,   1.20319553e-01,
#           8.99521179e+01],
#        [ -2.40878598e-03,   6.18761301e-01,  -6.19903326e-01,
#          -6.49025269e+01],
#        [  1.69202648e-02,   8.80874842e-02,   4.35444641e+00,
#          -9.37881622e+01],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]])

# %%
data2.shape
# Out:
# (33, 320, 288)

# %%
img.get_data().shape
# Out:
# (288, 320, 33)

# %%
label = 'labels.nii.gz'

# %%
nib.save(nib.Nifti1Image(data2.swapaxes(0,2),img.affine), label)

# %%
label_img = nib.load(label)

# %%
label_img.get_data().shape
# Out:
# (288, 320, 33)

# %%
data2.swapaxes(0,2).shape
# Out:
# (288, 320, 33)

# %%
nib.save(nib.Nifti1Image(test,img.affine), 'data.nii.gz')

# %%
display = plotting.plot_img('data.nii.gz', cut_coords=[75,100,28])
display.add_overlay('tumor.nii.gz')
print "hi"
# Out:
# hi
# /usr/local/lib/python2.7/dist-packages/numpy/ma/core.py:2766: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)

# %%
display = plotting.plot_img(filename,display_mode='z',cut_coords=range(20,22))
display.add_overlay('tumor.nii.gz', threshold=0,cmap=plotting.cm.purple_blue)
# Out:
# /root/.local/lib/python2.7/site-packages/nilearn/image/resampling.py:472: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %%
display = plotting.plot_img(label,display_mode='z',cut_coords=range(20,25))

# %%
np.

# %%
filename2 = 'tumor.nii.gz'
img2 = nib.load(filename2)

# %%
img.get_data().shape
# Out:
# (288, 320, 33)
