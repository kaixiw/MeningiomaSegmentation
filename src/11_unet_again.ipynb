# %%
from keras.models import load_model
from keras import backend as K
K.set_image_dim_ordering('th')

model = load_model('vgg16.h5')

# %%
import tensorflow as tf
from keras.models import Model
from keras.layers.convolutional import UpSampling2D, ZeroPadding2D, Conv2D
from keras.layers.local import LocallyConnected1D
from keras.layers.normalization import BatchNormalization
from keras.layers import Activation, Input, Lambda, Flatten, Dense, Reshape
from keras.layers.merge import concatenate
#from keras.layers.activation import softmax
from keras.optimizers import SGD
import keras.activations
import numpy as np

# https://github.com/jocicmarko/ultrasound-nerve-segmentation/blob/master/train.py#L19
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def addConv(x, n, filters, activation='relu'):
    for _ in range(n):
        x = ZeroPadding2D(1)(x)
        x = Conv2D(filters, 3)(x)
        x = BatchNormalization()(x)
        x = Activation(activation) (x)
    return x


inp = Input(shape=(1,224,224))
inp0 = Lambda(lambda y:tf.tile(y,[1,3,1,1])) (inp)

m = Model(inputs = model.inputs, outputs = model.layers[15].output)
m.trainable = False
x = m(inp0)

size_224 = m.layers[3].output
size_112 = m.layers[9].output
m_112 = Model(inputs = model.inputs, outputs = model.layers[8].output)
m_112.trainable = False
x_112 = m_112(inp0)
m_224 = Model(inputs = model.inputs, outputs = model.layers[3].output)
m_224.trainable = False
x_224 = m_224(inp0)


x = UpSampling2D(2)(x)
x = addConv(x, 2, 64)
x = concatenate([x,x_112],axis=1)





'''
x = UpSampling2D(2)(x)
x = addConv(x, 2, 64)

x = UpSampling2D(2)(x)
x = addConv(x, 2, 64)
'''
x = UpSampling2D(2)(x)
x = addConv(x, 1, 64)
x = concatenate([x,x_224],axis=1)

x = addConv(x, 2, 64)
x = addConv(x, 1, 2,'softmax')

m2 = Model(inputs = inp, outputs = x)
sgd = SGD(lr=1e1)
#m2.summary()
#m2.compile(loss=dice_coef_loss, optimizer='adadelta',metrics=[dice_coef,'accuracy'])
m2.compile(loss='binary_crossentropy', optimizer='adadelta',metrics=['binary_crossentropy'])

# %%
m2.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_6 (InputLayer)             (None, 1, 224, 224)   0
# ____________________________________________________________________________________________________
# lambda_6 (Lambda)                (None, 3, 224, 224)   0           input_6[0][0]
# ____________________________________________________________________________________________________
# model_21 (Model)                 (None, 256, 56, 56)   1735488     lambda_6[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D)  (None, 256, 112, 112) 0           model_21[1][0]
# ____________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2D (None, 256, 114, 114) 0           up_sampling2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_28 (Conv2D)               (None, 64, 112, 112)  147520      zero_padding2d_28[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_28 (BatchNor (None, 64, 112, 112)  448         conv2d_28[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, 64, 112, 112)  0           batch_normalization_28[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2D (None, 64, 114, 114)  0           activation_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_29 (Conv2D)               (None, 64, 112, 112)  36928       zero_padding2d_29[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_29 (BatchNor (None, 64, 112, 112)  448         conv2d_29[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, 64, 112, 112)  0           batch_normalization_29[0][0]
# ____________________________________________________________________________________________________
# model_22 (Model)                 (None, 128, 112, 112) 260160      lambda_6[0][0]
# ____________________________________________________________________________________________________
# concatenate_11 (Concatenate)     (None, 192, 112, 112) 0           activation_29[0][0]
#                                                                    model_22[1][0]
# ____________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D)  (None, 192, 224, 224) 0           concatenate_11[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2D (None, 192, 226, 226) 0           up_sampling2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_30 (Conv2D)               (None, 64, 224, 224)  110656      zero_padding2d_30[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_30 (BatchNor (None, 64, 224, 224)  896         conv2d_30[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, 64, 224, 224)  0           batch_normalization_30[0][0]
# ____________________________________________________________________________________________________
# model_23 (Model)                 (None, 64, 224, 224)  38720       lambda_6[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, 128, 224, 224) 0           activation_30[0][0]
#                                                                    model_23[1][0]
# ____________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2D (None, 128, 226, 226) 0           concatenate_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_31 (Conv2D)               (None, 64, 224, 224)  73792       zero_padding2d_31[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_31 (BatchNor (None, 64, 224, 224)  896         conv2d_31[0][0]
# ____________________________________________________________________________________________________
# activation_31 (Activation)       (None, 64, 224, 224)  0           batch_normalization_31[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2D (None, 64, 226, 226)  0           activation_31[0][0]
# ____________________________________________________________________________________________________
# conv2d_32 (Conv2D)               (None, 64, 224, 224)  36928       zero_padding2d_32[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_32 (BatchNor (None, 64, 224, 224)  896         conv2d_32[0][0]
# ____________________________________________________________________________________________________
# activation_32 (Activation)       (None, 64, 224, 224)  0           batch_normalization_32[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2D (None, 64, 226, 226)  0           activation_32[0][0]
# ____________________________________________________________________________________________________
# conv2d_33 (Conv2D)               (None, 2, 224, 224)   1154        zero_padding2d_33[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_33 (BatchNor (None, 2, 224, 224)   896         conv2d_33[0][0]
# ____________________________________________________________________________________________________
# activation_33 (Activation)       (None, 2, 224, 224)   0           batch_normalization_33[0][0]
# ====================================================================================================
# Total params: 2,146,946
# Trainable params: 409,218
# Non-trainable params: 1,737,728
# ____________________________________________________________________________________________________

# %%
np.concatenate((train_y,train_y),axis=1).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3e3d5616942a> in <module>()
# ----> 1 np.concatenate((train_y,train_y),axis=1).shape
#
# NameError: name 'train_y' is not defined

# %%
from scipy.misc import imresize
def preprocess_labels(labels):
    pos = np.where(labels==1)
    new_labels = np.concatenate((labels,labels),axis=1)
    new_labels.fill(0)
    new_labels[:,0]= 1
    new_labels[pos[0], 0, pos[2],pos[3]] = 0
    new_labels[pos[0], 1, pos[2],pos[3]] = 1
    #new_labels = new_labels.transpose((2,0,1))
    return new_labels

def preprocess(mri_slice):
    img0 = imresize(mri_slice, (224,224))
    img0.resize((img0.shape[0],img0.shape[1],1))
    img0 = img0.transpose((2,0,1))
    return np.expand_dims(img0, axis=0)

# %%
#f = h5py.File('dataset_1_equal.h5', 'r')
#train_y = f['train_y'][:end]
#f.close()
#pre = train_y.reshape(train_y.shape[0],train_y.shape[2],train_y.shape[3])
np.where(pre==None)
#np.where(train_y==None)
#pre = preprocess_labels1(train_y)
#img = pre[18]
#pos = np.where(np.argmax(img, axis=0)>0)
#img1 = np.zeros((img.shape[1],img.shape[2]))
#img1[pos[0],pos[1]] = 1
#print(img1.shape)
#plt.imshow(img1)
#m2.reset_states()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:5: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# (array([], dtype=int64),)

# %%
import h5py
cont = 100
initial_epoch = 5
epochs = 5
for i in range(0,1000,100):
    start = cont+i
    end = start+100
    with h5py.File('dataset_1_equal.h5', 'r') as f:
        train_x = f['train_x'][start:end]
        train_y = preprocess_labels(f['train_y'][start:end])
        #train_y = f['train_y'][start:end]
        #train_y = train_y.reshape(train_y.shape[0],train_y.shape[2],train_y.shape[3])
        print(m2.evaluate(train_x[0:1],train_y[0:1],batch_size=5))
        m2.fit(train_x,train_y,epochs=initial_epoch+epochs,batch_size=5,initial_epoch=initial_epoch,shuffle="batch")
        #draw_fig(fig,ax)
    initial_epoch+=epochs
# Out:
# 1/1 [==============================] - 0s
# [2.7094907760620117, 2.7094907760620117]
# Epoch 6/10
# 100/100 [==============================] - 21s - loss: 2.7089 - binary_crossentropy: 2.7089
# Epoch 7/10
# 100/100 [==============================] - 21s - loss: 2.7076 - binary_crossentropy: 2.7076
# Epoch 8/10
# 100/100 [==============================] - 21s - loss: 2.7072 - binary_crossentropy: 2.7072
# Epoch 9/10
# 100/100 [==============================] - 21s - loss: 2.7068 - binary_crossentropy: 2.7068
# Epoch 10/10
# 100/100 [==============================] - 21s - loss: 2.7065 - binary_crossentropy: 2.7065
# 1/1 [==============================] - 0s
# [2.7080626487731934, 2.7080624103546143]
# Epoch 11/15
# 100/100 [==============================] - 21s - loss: 2.7093 - binary_crossentropy: 2.7093
# Epoch 12/15
# 100/100 [==============================] - 21s - loss: 2.7089 - binary_crossentropy: 2.7089
# Epoch 13/15
# 100/100 [==============================] - 21s - loss: 2.7087 - binary_crossentropy: 2.7087
# Epoch 14/15
# 100/100 [==============================] - 21s - loss: 2.7086 - binary_crossentropy: 2.7086
# Epoch 15/15
# 100/100 [==============================] - 21s - loss: 2.7085 - binary_crossentropy: 2.7085
# 1/1 [==============================] - 0s
# [2.7086911201477051, 2.7086911201477051]
# Epoch 16/20
# 100/100 [==============================] - 21s - loss: 2.7088 - binary_crossentropy: 2.7088
# Epoch 17/20
# 100/100 [==============================] - 21s - loss: 2.7084 - binary_crossentropy: 2.7084
# Epoch 18/20
# 100/100 [==============================] - 21s - loss: 2.7082 - binary_crossentropy: 2.7082
# Epoch 19/20
# 100/100 [==============================] - 21s - loss: 2.7080 - binary_crossentropy: 2.7080
# Epoch 20/20
# 100/100 [==============================] - 21s - loss: 2.7079 - binary_crossentropy: 2.7079
# 1/1 [==============================] - 0s
# [2.70878005027771, 2.7087802886962891]
# Epoch 21/25
# 100/100 [==============================] - 21s - loss: 2.7071 - binary_crossentropy: 2.7071
# Epoch 22/25
# 100/100 [==============================] - 21s - loss: 2.7066 - binary_crossentropy: 2.7066
# Epoch 23/25
# 100/100 [==============================] - 21s - loss: 2.7064 - binary_crossentropy: 2.7064
# Epoch 24/25
# 100/100 [==============================] - 21s - loss: 2.7063 - binary_crossentropy: 2.7063
# Epoch 25/25
# 100/100 [==============================] - 21s - loss: 2.7062 - binary_crossentropy: 2.7062
# 1/1 [==============================] - 0s
# [2.7087929248809814, 2.7087931632995605]
# Epoch 26/30
# 100/100 [==============================] - 21s - loss: 2.7052 - binary_crossentropy: 2.7052
# Epoch 27/30
# 100/100 [==============================] - 21s - loss: 2.7047 - binary_crossentropy: 2.7047
# Epoch 28/30
# 100/100 [==============================] - 21s - loss: 2.7045 - binary_crossentropy: 2.7045
# Epoch 29/30
# 100/100 [==============================] - 21s - loss: 2.7044 - binary_crossentropy: 2.7044
# Epoch 30/30
# 100/100 [==============================] - 21s - loss: 2.7042 - binary_crossentropy: 2.7042
# 1/1 [==============================] - 0s
# [2.7092700004577637, 2.7092697620391846]
# Epoch 31/35
# 100/100 [==============================] - 21s - loss: 2.7050 - binary_crossentropy: 2.7050
# Epoch 32/35
# 100/100 [==============================] - 21s - loss: 2.7045 - binary_crossentropy: 2.7045
# Epoch 33/35
# 100/100 [==============================] - 21s - loss: 2.7043 - binary_crossentropy: 2.7043
# Epoch 34/35
# 100/100 [==============================] - 21s - loss: 2.7040 - binary_crossentropy: 2.7040
# Epoch 35/35
# 100/100 [==============================] - 21s - loss: 2.7039 - binary_crossentropy: 2.7039
# 1/1 [==============================] - 0s
# [2.7083373069763184, 2.7083373069763184]
# Epoch 36/40
# 100/100 [==============================] - 21s - loss: 2.7021 - binary_crossentropy: 2.7021
# Epoch 37/40
# 100/100 [==============================] - 21s - loss: 2.7012 - binary_crossentropy: 2.7012
# Epoch 38/40
# 100/100 [==============================] - 21s - loss: 2.7008 - binary_crossentropy: 2.7008
# Epoch 39/40
# 100/100 [==============================] - 21s - loss: 2.7004 - binary_crossentropy: 2.7004
# Epoch 40/40
# 100/100 [==============================] - 21s - loss: 2.7004 - binary_crossentropy: 2.7004
# 1/1 [==============================] - 0s
# [2.7083756923675537, 2.7083754539489746]
# Epoch 41/45
# 70/70 [==============================] - 14s - loss: 2.7021 - binary_crossentropy: 2.7021
# Epoch 42/45
# 70/70 [==============================] - 14s - loss: 2.7019 - binary_crossentropy: 2.7019
# Epoch 43/45
# 70/70 [==============================] - 14s - loss: 2.7018 - binary_crossentropy: 2.7018
# Epoch 44/45
# 70/70 [==============================] - 14s - loss: 2.7017 - binary_crossentropy: 2.7017
# Epoch 45/45
# 70/70 [==============================] - 14s - loss: 2.7015 - binary_crossentropy: 2.7015
# []
# Epoch 46/50
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-c38ee64f5b57> in <module>()
#      12         #train_y = train_y.reshape(train_y.shape[0],train_y.shape[2],train_y.shape[3])
#      13         print(m2.evaluate(train_x[0:1],train_y[0:1],batch_size=5))
# ---> 14         m2.fit(train_x,train_y,epochs=initial_epoch+epochs,batch_size=5,initial_epoch=initial_epoch,shuffle="batch")
#      15         #draw_fig(fig,ax)
#      16     initial_epoch+=epochs
#
# /home/kaixi/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/kaixi/.local/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1168                         for l, o in zip(out_labels, val_outs):
#    1169                             epoch_logs['val_' + l] = o
# -> 1170             callbacks.on_epoch_end(epoch, epoch_logs)
#    1171             if callback_model.stop_training:
#    1172                 break
#
# /home/kaixi/.local/lib/python3.5/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#      75         logs = logs or {}
#      76         for callback in self.callbacks:
# ---> 77             callback.on_epoch_end(epoch, logs)
#      78
#      79     def on_batch_begin(self, batch, logs=None):
#
# /home/kaixi/.local/lib/python3.5/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     292                 self.log_values.append((k, logs[k]))
#     293         if self.verbose:
# --> 294             self.progbar.update(self.seen, self.log_values, force=True)
#     295
#     296
#
# AttributeError: 'ProgbarLogger' object has no attribute 'log_values'

# %%
def draw_fig(fig,ax):
    fig.clear()
    img= m2.predict(preprocess(mri_data[predict_slide])).squeeze()
    ax.imshow(imresize(mri_data[predict_slide], (224,224)),cmap=plt.cm.gray)
    ax.imshow(np.ma.masked_where(img1<.5, img1),alpha=.7,cmap=plt.cm.autumn, interpolation='none')
    print (img.sum())

# %%
img.max()
# Out:
# 0.9999994

# %%
# Get image data w/ nibabel
import nibabel as nib
def get_data(filename):
    img = nib.load(filename)
    return img.get_data()
def scale(array):
    return (array-np.min(array))/(np.max(array) - np.min(array))    
mri_data = scale(get_data('../data/case_046_2.nii.gz')).transpose((2,0,1))
labelled_data = get_data('../data/case_046_labels.nii.gz').transpose((2,0,1))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

predict_slide = 140

img= m2.predict(preprocess(mri_data[predict_slide])).squeeze()
pos = np.where(np.argmax(img, axis=0)>0)
img1 = np.zeros((img.shape[1],img.shape[2]))
img1[pos[0],pos[1]] = img[1,pos[0],pos[1]]
img1/=img1.max()
fig, ax = plt.subplots(1,2)
fig.set_size_inches(15,15)
ax[0].imshow(imresize(mri_data[predict_slide], (224,224)),cmap=plt.cm.gray)
#ax[0].imshow(np.ma.masked_where(img1<=np.average(img1)+np.std(img1), img1),alpha=.7,cmap=plt.cm.Reds, interpolation='none')
ax[0].imshow(np.ma.masked_where(img1<=0, img1),alpha=.7,cmap=plt.cm.Reds, interpolation='none')

# Show original
ax[1].imshow(imresize(mri_data[predict_slide], (224,224)),cmap=plt.cm.gray)
labels = imresize(labelled_data[predict_slide],(224,224))
ax[1].imshow(np.ma.masked_where(labels<=0, labels),cmap=plt.cm.autumn, alpha=0.1)
img1.sum()

# %%
ax.shape
# Out:
# (2,)

# %%
import nibabel as nib
import numpy as np
from scipy.misc import imresize
def get_data(filename):
    img = nib.load(filename)
    return img.get_data()
def scale(array):
    return (array-np.min(array))/(np.max(array) - np.min(array))    
def load(s):
    return get_data('../data/case_%s_2.nii.gz'%s).transpose((2,0,1)), get_data('../data/case_%s_labels.nii.gz'%s).transpose((2,0,1))
def preprocess(mri_slice):
    img0 = imresize(mri_slice, (224,224))
    img0.resize((img0.shape[0],img0.shape[1],1))
    img0 = img0.transpose((2,0,1))
    return np.expand_dims(img0, axis=0)
def get_testing_data(s):
    x, y = load(s)
    
    x = scale(x)
    
    x1 = np.zeros((x.shape[0],1,224, 224,))
    y1 = np.zeros(x1.shape)
    
    for n in range(x.shape[0]):
        x1[n] = preprocess(x[n])
        y1[n] = preprocess(y[n])
    return x1, y1
def get_training_data(s, slice_filter="equal"):
    print("Getting data for",s)
    x, y = load(s)
    
    x_sums_by_slice = x.sum(axis=(1,2)) # used to avoid completely blank slices
    y_sums_by_slice = y.sum(axis=(1,2))
    
    # Get slice #s for slices with/out patches
    patch_slices = np.where(y_sums_by_slice>0)[0]
    non_patch_slices = np.where((y_sums_by_slice==0) & (x_sums_by_slice>0))[0]
    np.random.shuffle(non_patch_slices)
        
    # Filter
    if slice_filter == "equal":
        #print (non_patch_slices)
        non_patch_slices = non_patch_slices[:patch_slices.size]
        #print (non_patch_slices)
    if slice_filter == "patches_only":
        non_patch_slices = []
    
    all_slices = np.concatenate((patch_slices,non_patch_slices)).astype(int)
    all_slices.sort()
    
    # preprocess data    
    x = scale(x)
    
    x1 = np.zeros((all_slices.size,1,224, 224,))
    y1 = np.zeros(x1.shape)
    
    for n,slice_n in enumerate(all_slices):
        x1[n] = preprocess(x[slice_n])
        y1[n] = preprocess(y[slice_n])
    
    return x1, preprocess_labels(y1)

# %%
import glob
def get_case_num(name):    
    return name[name.find("case_")+len("case_"):name.find("_labels")]

all_cases = []
for name in glob.glob('../data/*labels.nii.gz'):
    print(name,get_case_num(name))
    all_cases.append(get_case_num(name))
all_cases.sort()
# Out:
# ../data/case_021_labels.nii.gz 021
# ../data/case_011_labels.nii.gz 011
# ../data/case_018_labels.nii.gz 018
# ../data/case_047_labels.nii.gz 047
# ../data/case_055_labels.nii.gz 055
# ../data/case_035_labels.nii.gz 035
# ../data/case_007_labels.nii.gz 007
# ../data/case_039_labels.nii.gz 039
# ../data/case_019_labels.nii.gz 019
# ../data/case_008_labels.nii.gz 008
# ../data/case_053_labels.nii.gz 053
# ../data/case_004_labels.nii.gz 004
# ../data/case_058_labels.nii.gz 058
# ../data/case_028_labels.nii.gz 028
# ../data/case_017_labels.nii.gz 017
# ../data/case_010_labels.nii.gz 010
# ../data/case_002_labels.nii.gz 002
# ../data/case_034_labels.nii.gz 034
# ../data/case_014_labels.nii.gz 014
# ../data/case_001_labels.nii.gz 001
# ../data/case_046_labels.nii.gz 046
# ../data/case_009_labels.nii.gz 009
# ../data/case_005_labels.nii.gz 005
# ../data/case_013_labels.nii.gz 013
# ../data/case_052_labels.nii.gz 052
# ../data/case_003_labels.nii.gz 003

# %%
import h5py
cont = 100
initial_epoch = 1
epochs = 5
for case in all_cases[:5]:
    train_x,train_y = get_training_data(case,'all')
    m2.fit(train_x,train_y,epochs=initial_epoch+epochs,batch_size=5,initial_epoch=initial_epoch,shuffle="batch")
    initial_epoch+=epochs
# Out:
# Getting data for 001
# Epoch 2/6
# 33/33 [==============================] - 10s - loss: 2.9432 - binary_crossentropy: 2.9432
# Epoch 3/6
# 33/33 [==============================] - 8s - loss: 2.7193 - binary_crossentropy: 2.7193
# Epoch 4/6
# 33/33 [==============================] - 8s - loss: 2.7112 - binary_crossentropy: 2.7112
# Epoch 5/6
# 33/33 [==============================] - 8s - loss: 2.7105 - binary_crossentropy: 2.7105
# Epoch 6/6
# 33/33 [==============================] - 8s - loss: 2.7099 - binary_crossentropy: 2.7099
# Getting data for 002
# Epoch 7/11
# 27/27 [==============================] - 7s - loss: 2.7102 - binary_crossentropy: 2.7102
# Epoch 8/11
# 27/27 [==============================] - 6s - loss: 2.7096 - binary_crossentropy: 2.7096
# Epoch 9/11
# 27/27 [==============================] - 6s - loss: 2.7094 - binary_crossentropy: 2.7094
# Epoch 10/11
# 27/27 [==============================] - 6s - loss: 2.7092 - binary_crossentropy: 2.7092
# Epoch 11/11
# 27/27 [==============================] - 6s - loss: 2.7091 - binary_crossentropy: 2.7091
# Getting data for 003
# Epoch 12/16
# 32/32 [==============================] - 7s - loss: 2.7092 - binary_crossentropy: 2.7092
# Epoch 13/16
# 32/32 [==============================] - 7s - loss: 2.7089 - binary_crossentropy: 2.7089
# Epoch 14/16
# 32/32 [==============================] - 7s - loss: 2.7091 - binary_crossentropy: 2.7091
# Epoch 15/16
# 32/32 [==============================] - 7s - loss: 2.7089 - binary_crossentropy: 2.7089
# Epoch 16/16
# 32/32 [==============================] - 7s - loss: 2.7087 - binary_crossentropy: 2.7087
# Getting data for 004
# Epoch 17/21
# 174/174 [==============================] - 43s - loss: 2.7081 - binary_crossentropy: 2.7081
# Epoch 18/21
# 174/174 [==============================] - 42s - loss: 2.7078 - binary_crossentropy: 2.7078
# Epoch 19/21
# 174/174 [==============================] - 42s - loss: 2.7076 - binary_crossentropy: 2.7076
# Epoch 20/21
# 174/174 [==============================] - 42s - loss: 2.7074 - binary_crossentropy: 2.7074
# Epoch 21/21
# 174/174 [==============================] - 42s - loss: 2.7072 - binary_crossentropy: 2.7072
# Getting data for 005
# Epoch 22/26
# 196/196 [==============================] - 48s - loss: 2.7083 - binary_crossentropy: 2.7083
# Epoch 23/26
# 196/196 [==============================] - 48s - loss: 2.7081 - binary_crossentropy: 2.7081
# Epoch 24/26
# 196/196 [==============================] - 48s - loss: 2.7081 - binary_crossentropy: 2.7081
# Epoch 25/26
# 196/196 [==============================] - 48s - loss: 2.7080 - binary_crossentropy: 2.7080
# Epoch 26/26
# 196/196 [==============================] - 48s - loss: 2.7080 - binary_crossentropy: 2.7080

# %%
from keras.models import load_model
m3 = load_model('Model_unet_case1-5_5ep.h5')
