# %% [markdown]
# # Modifying pretrained model

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout, Activation
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
import cv2, numpy as np

from keras import backend as K

K.set_image_dim_ordering('th')

model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
model.add(Conv2D(64, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
'''
model.add(Conv2D(128, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(64, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
'''
model.add(Conv2D(32, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))

model.add(Conv2D(2, 3, 3, activation='softmax'))
#model.add(Activation(2, 1, 1, activation='sigmoid'))
#model.add(Conv2D(2, 1, 1, activation='sigmoid'))
model.summary()

# https://github.com/jocicmarko/ultrasound-nerve-segmentation/blob/master/train.py#L19
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['categorical_crossentropy','accuracy'])
          #loss=dice_coef_loss, metrics=[dice_coef,'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_16 (ZeroPaddi (None, 3, 226, 226)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 64, 224, 224)      1792
# _________________________________________________________________
# zero_padding2d_17 (ZeroPaddi (None, 64, 226, 226)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 224, 224)      18464
# _________________________________________________________________
# zero_padding2d_18 (ZeroPaddi (None, 32, 226, 226)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 224, 224)       578
# =================================================================
# Total params: 20,834
# Trainable params: 20,834
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(2, (3, 3), activation="softmax")`

# %%
model.fit(x_train,y_train,epochs=500,verbose=2)
#m.fit(preprocess(mri_data[:,:,20]),preprocess(labelled_data[:,:,20], False),epochs=20)
# Out:
# Epoch 1/500
# 0s - loss: 1043.5720 - categorical_crossentropy: 1043.5721 - acc: 0.0848
# Epoch 2/500
# 0s - loss: 1480.8684 - categorical_crossentropy: 1480.8684 - acc: 0.0012
# Epoch 3/500
# 0s - loss: 1412.0901 - categorical_crossentropy: 1412.0901 - acc: 4.9603e-04
# Epoch 4/500
# 0s - loss: 736.1298 - categorical_crossentropy: 736.1297 - acc: 0.0012
# Epoch 5/500
# 0s - loss: 1053.3611 - categorical_crossentropy: 1053.3612 - acc: 0.2418
# Epoch 6/500
# 0s - loss: 785.9198 - categorical_crossentropy: 785.9199 - acc: 0.0565
# Epoch 7/500
# 0s - loss: 963.2289 - categorical_crossentropy: 963.2291 - acc: 0.0025
# Epoch 8/500
# 0s - loss: 772.1252 - categorical_crossentropy: 772.1253 - acc: 0.0856
# Epoch 9/500
# 0s - loss: 619.9008 - categorical_crossentropy: 619.9007 - acc: 7.4405e-04
# Epoch 10/500
# 0s - loss: 616.2150 - categorical_crossentropy: 616.2149 - acc: 4.9603e-04
# Epoch 11/500
# 0s - loss: 618.7922 - categorical_crossentropy: 618.7922 - acc: 9.9206e-04
# Epoch 12/500
# 0s - loss: 644.1367 - categorical_crossentropy: 644.1367 - acc: 4.9603e-04
# Epoch 13/500
# 0s - loss: 699.5489 - categorical_crossentropy: 699.5488 - acc: 0.0709
# Epoch 14/500
# 0s - loss: 612.1510 - categorical_crossentropy: 612.1509 - acc: 0.0012
# Epoch 15/500
# 0s - loss: 612.0892 - categorical_crossentropy: 612.0892 - acc: 0.0020
# Epoch 16/500
# 0s - loss: 614.0597 - categorical_crossentropy: 614.0596 - acc: 0.0015
# Epoch 17/500
# 0s - loss: 625.9667 - categorical_crossentropy: 625.9667 - acc: 0.0164
# Epoch 18/500
# 0s - loss: 622.8912 - categorical_crossentropy: 622.8912 - acc: 0.0012
# Epoch 19/500
# 0s - loss: 638.9070 - categorical_crossentropy: 638.9070 - acc: 0.0275
# Epoch 20/500
# 0s - loss: 611.2118 - categorical_crossentropy: 611.2118 - acc: 0.0025
# Epoch 21/500
# 0s - loss: 613.6630 - categorical_crossentropy: 613.6630 - acc: 0.0040
# Epoch 22/500
# 0s - loss: 610.9045 - categorical_crossentropy: 610.9044 - acc: 0.0020
# Epoch 23/500
# 0s - loss: 614.9948 - categorical_crossentropy: 614.9947 - acc: 0.0082
# Epoch 24/500
# 0s - loss: 611.6214 - categorical_crossentropy: 611.6215 - acc: 0.0027
# Epoch 25/500
# 0s - loss: 615.2460 - categorical_crossentropy: 615.2460 - acc: 0.0104
# Epoch 26/500
# 0s - loss: 611.0791 - categorical_crossentropy: 611.0791 - acc: 0.0025
# Epoch 27/500
# 0s - loss: 614.6218 - categorical_crossentropy: 614.6218 - acc: 0.0112
# Epoch 28/500
# 0s - loss: 611.2058 - categorical_crossentropy: 611.2058 - acc: 0.0025
# Epoch 29/500
# 0s - loss: 615.4335 - categorical_crossentropy: 615.4335 - acc: 0.0164
# Epoch 30/500
# 0s - loss: 611.0302 - categorical_crossentropy: 611.0302 - acc: 0.0027
# Epoch 31/500
# 0s - loss: 614.9758 - categorical_crossentropy: 614.9757 - acc: 0.0159
# Epoch 32/500
# 0s - loss: 610.3530 - categorical_crossentropy: 610.3530 - acc: 0.0027
# Epoch 33/500
# 0s - loss: 613.7387 - categorical_crossentropy: 613.7387 - acc: 0.0161
# Epoch 34/500
# 0s - loss: 609.6653 - categorical_crossentropy: 609.6653 - acc: 0.0027
# Epoch 35/500
# 0s - loss: 612.5415 - categorical_crossentropy: 612.5414 - acc: 0.0159
# Epoch 36/500
# 0s - loss: 609.1796 - categorical_crossentropy: 609.1796 - acc: 0.0025
# Epoch 37/500
# 0s - loss: 611.8275 - categorical_crossentropy: 611.8275 - acc: 0.0149
# Epoch 38/500
# 0s - loss: 608.8517 - categorical_crossentropy: 608.8517 - acc: 0.0030
# Epoch 39/500
# 0s - loss: 611.4141 - categorical_crossentropy: 611.4140 - acc: 0.0124
# Epoch 40/500
# 0s - loss: 608.5844 - categorical_crossentropy: 608.5844 - acc: 0.0032
# Epoch 41/500
# 0s - loss: 610.9108 - categorical_crossentropy: 610.9108 - acc: 0.0102
# Epoch 42/500
# 0s - loss: 608.0518 - categorical_crossentropy: 608.0517 - acc: 0.0025
# Epoch 43/500
# 0s - loss: 610.1273 - categorical_crossentropy: 610.1274 - acc: 0.0141
# Epoch 44/500
# 0s - loss: 608.1643 - categorical_crossentropy: 608.1644 - acc: 0.0015
# Epoch 45/500
# 0s - loss: 609.8384 - categorical_crossentropy: 609.8384 - acc: 0.0117
# Epoch 46/500
# 0s - loss: 607.5295 - categorical_crossentropy: 607.5295 - acc: 0.0017
# Epoch 47/500
# 0s - loss: 609.5659 - categorical_crossentropy: 609.5660 - acc: 0.0064
# Epoch 48/500
# 0s - loss: 606.9745 - categorical_crossentropy: 606.9745 - acc: 0.0030
# Epoch 49/500
# 0s - loss: 608.3314 - categorical_crossentropy: 608.3314 - acc: 0.0067
# Epoch 50/500
# 0s - loss: 606.8522 - categorical_crossentropy: 606.8521 - acc: 0.0012
# Epoch 51/500
# 0s - loss: 608.1818 - categorical_crossentropy: 608.1818 - acc: 0.0084
# Epoch 52/500
# 0s - loss: 607.4395 - categorical_crossentropy: 607.4395 - acc: 0.0025
# Epoch 53/500
# 0s - loss: 608.8550 - categorical_crossentropy: 608.8550 - acc: 0.0099
# Epoch 54/500
# 0s - loss: 606.3346 - categorical_crossentropy: 606.3346 - acc: 0.0012
# Epoch 55/500
# 0s - loss: 607.0019 - categorical_crossentropy: 607.0018 - acc: 0.0087
# Epoch 56/500
# 0s - loss: 605.7808 - categorical_crossentropy: 605.7808 - acc: 0.0012
# Epoch 57/500
# 0s - loss: 606.3352 - categorical_crossentropy: 606.3352 - acc: 0.0104
# Epoch 58/500
# 0s - loss: 605.7659 - categorical_crossentropy: 605.7659 - acc: 7.4405e-04
# Epoch 59/500
# 0s - loss: 606.6599 - categorical_crossentropy: 606.6599 - acc: 0.0107
# Epoch 60/500
# 0s - loss: 605.3158 - categorical_crossentropy: 605.3158 - acc: 7.4405e-04
# Epoch 61/500
# 0s - loss: 605.5720 - categorical_crossentropy: 605.5720 - acc: 0.0067
# Epoch 62/500
# 0s - loss: 605.6660 - categorical_crossentropy: 605.6659 - acc: 0.0022
# Epoch 63/500
# 0s - loss: 607.4165 - categorical_crossentropy: 607.4165 - acc: 0.0052
# Epoch 64/500
# 0s - loss: 606.8160 - categorical_crossentropy: 606.8160 - acc: 4.9603e-04
# Epoch 65/500
# 0s - loss: 607.1609 - categorical_crossentropy: 607.1609 - acc: 0.0087
# Epoch 66/500
# 0s - loss: 605.1006 - categorical_crossentropy: 605.1006 - acc: 0.0020
# Epoch 67/500
# 0s - loss: 604.4210 - categorical_crossentropy: 604.4211 - acc: 0.0027
# Epoch 68/500
# 0s - loss: 604.0494 - categorical_crossentropy: 604.0494 - acc: 9.9206e-04
# Epoch 69/500
# 0s - loss: 604.3494 - categorical_crossentropy: 604.3492 - acc: 0.0060
# Epoch 70/500
# 0s - loss: 604.7937 - categorical_crossentropy: 604.7937 - acc: 0.0012
# Epoch 71/500
# 0s - loss: 606.2589 - categorical_crossentropy: 606.2589 - acc: 0.0099
# Epoch 72/500
# 0s - loss: 605.1031 - categorical_crossentropy: 605.1031 - acc: 0.0012
# Epoch 73/500
# 0s - loss: 605.7673 - categorical_crossentropy: 605.7673 - acc: 0.0069
# Epoch 74/500
# 0s - loss: 605.2350 - categorical_crossentropy: 605.2350 - acc: 0.0012
# Epoch 75/500
# 0s - loss: 604.6224 - categorical_crossentropy: 604.6224 - acc: 0.0060
# Epoch 76/500
# 0s - loss: 604.2711 - categorical_crossentropy: 604.2711 - acc: 7.4405e-04
# Epoch 77/500
# 0s - loss: 605.3488 - categorical_crossentropy: 605.3488 - acc: 0.0047
# Epoch 78/500
# 0s - loss: 605.4098 - categorical_crossentropy: 605.4097 - acc: 9.9206e-04
# Epoch 79/500
# 0s - loss: 605.7260 - categorical_crossentropy: 605.7260 - acc: 0.0084
# Epoch 80/500
# 0s - loss: 604.3967 - categorical_crossentropy: 604.3967 - acc: 0.0012
# Epoch 81/500
# 0s - loss: 604.4310 - categorical_crossentropy: 604.4309 - acc: 0.0089
# Epoch 82/500
# 0s - loss: 603.6321 - categorical_crossentropy: 603.6321 - acc: 9.9206e-04
# Epoch 83/500
# 0s - loss: 603.5260 - categorical_crossentropy: 603.5260 - acc: 0.0037
# Epoch 84/500
# 0s - loss: 603.5124 - categorical_crossentropy: 603.5124 - acc: 0.0015
# Epoch 85/500
# 0s - loss: 603.6414 - categorical_crossentropy: 603.6414 - acc: 0.0027
# Epoch 86/500
# 0s - loss: 603.3209 - categorical_crossentropy: 603.3210 - acc: 0.0015
# Epoch 87/500
# 0s - loss: 603.6626 - categorical_crossentropy: 603.6626 - acc: 0.0042
# Epoch 88/500
# 0s - loss: 603.6635 - categorical_crossentropy: 603.6634 - acc: 0.0020
# Epoch 89/500
# 0s - loss: 604.2269 - categorical_crossentropy: 604.2269 - acc: 0.0084
# Epoch 90/500
# 0s - loss: 604.4531 - categorical_crossentropy: 604.4531 - acc: 9.9206e-04
# Epoch 91/500
# 0s - loss: 604.8522 - categorical_crossentropy: 604.8522 - acc: 0.0045
# Epoch 92/500
# 0s - loss: 604.8070 - categorical_crossentropy: 604.8070 - acc: 4.9603e-04
# Epoch 93/500
# 0s - loss: 604.4663 - categorical_crossentropy: 604.4664 - acc: 0.0084
# Epoch 94/500
# 0s - loss: 603.7119 - categorical_crossentropy: 603.7118 - acc: 0.0017
# Epoch 95/500
# 0s - loss: 603.6273 - categorical_crossentropy: 603.6273 - acc: 0.0069
# Epoch 96/500
# 0s - loss: 603.0631 - categorical_crossentropy: 603.0632 - acc: 0.0012
# Epoch 97/500
# 0s - loss: 603.6532 - categorical_crossentropy: 603.6532 - acc: 0.0047
# Epoch 98/500
# 0s - loss: 603.7642 - categorical_crossentropy: 603.7642 - acc: 7.4405e-04
# Epoch 99/500
# 0s - loss: 603.9971 - categorical_crossentropy: 603.9970 - acc: 0.0045
# Epoch 100/500
# 0s - loss: 603.4456 - categorical_crossentropy: 603.4456 - acc: 0.0017
# Epoch 101/500
# 0s - loss: 603.4945 - categorical_crossentropy: 603.4944 - acc: 0.0040
# Epoch 102/500
# 0s - loss: 603.3304 - categorical_crossentropy: 603.3304 - acc: 4.9603e-04
# Epoch 103/500
# 0s - loss: 602.9230 - categorical_crossentropy: 602.9230 - acc: 0.0035
# Epoch 104/500
# 0s - loss: 602.8145 - categorical_crossentropy: 602.8145 - acc: 9.9206e-04
# Epoch 105/500
# 0s - loss: 602.9735 - categorical_crossentropy: 602.9736 - acc: 0.0037
# Epoch 106/500
# 0s - loss: 603.0496 - categorical_crossentropy: 603.0496 - acc: 7.4405e-04
# Epoch 107/500
# 0s - loss: 603.6329 - categorical_crossentropy: 603.6329 - acc: 0.0037
# Epoch 108/500
# 0s - loss: 603.2118 - categorical_crossentropy: 603.2118 - acc: 0.0020
# Epoch 109/500
# 0s - loss: 603.0396 - categorical_crossentropy: 603.0395 - acc: 0.0045
# Epoch 110/500
# 0s - loss: 603.2252 - categorical_crossentropy: 603.2252 - acc: 7.4405e-04
# Epoch 111/500
# 0s - loss: 603.6841 - categorical_crossentropy: 603.6841 - acc: 0.0062
# Epoch 112/500
# 0s - loss: 603.0604 - categorical_crossentropy: 603.0604 - acc: 0.0012
# Epoch 113/500
# 0s - loss: 602.7275 - categorical_crossentropy: 602.7275 - acc: 0.0015
# Epoch 114/500
# 0s - loss: 602.6223 - categorical_crossentropy: 602.6223 - acc: 0.0012
# Epoch 115/500
# 0s - loss: 602.6263 - categorical_crossentropy: 602.6263 - acc: 0.0040
# Epoch 116/500
# 0s - loss: 603.2007 - categorical_crossentropy: 603.2007 - acc: 9.9206e-04
# Epoch 117/500
# 0s - loss: 604.3309 - categorical_crossentropy: 604.3308 - acc: 0.0022
# Epoch 118/500
# 0s - loss: 604.0958 - categorical_crossentropy: 604.0958 - acc: 9.9206e-04
# Epoch 119/500
# 0s - loss: 603.9030 - categorical_crossentropy: 603.9030 - acc: 0.0022
# Epoch 120/500
# 0s - loss: 603.1086 - categorical_crossentropy: 603.1086 - acc: 4.9603e-04
# Epoch 121/500
# 0s - loss: 603.2159 - categorical_crossentropy: 603.2159 - acc: 0.0040
# Epoch 122/500
# 0s - loss: 603.3885 - categorical_crossentropy: 603.3885 - acc: 0.0015
# Epoch 123/500
# 0s - loss: 603.4565 - categorical_crossentropy: 603.4565 - acc: 0.0027
# Epoch 124/500
# 0s - loss: 603.1171 - categorical_crossentropy: 603.1170 - acc: 7.4405e-04
# Epoch 125/500
# 0s - loss: 602.7797 - categorical_crossentropy: 602.7797 - acc: 0.0015
# Epoch 126/500
# 0s - loss: 602.4533 - categorical_crossentropy: 602.4532 - acc: 7.4405e-04
# Epoch 127/500
# 0s - loss: 602.4323 - categorical_crossentropy: 602.4323 - acc: 0.0025
# Epoch 128/500
# 0s - loss: 602.4885 - categorical_crossentropy: 602.4885 - acc: 0.0012
# Epoch 129/500
# 0s - loss: 602.6973 - categorical_crossentropy: 602.6973 - acc: 0.0015
# Epoch 130/500
# 0s - loss: 602.3413 - categorical_crossentropy: 602.3413 - acc: 4.9603e-04
# Epoch 131/500
# 0s - loss: 602.3264 - categorical_crossentropy: 602.3264 - acc: 0.0035
# Epoch 132/500
# 0s - loss: 602.5206 - categorical_crossentropy: 602.5206 - acc: 7.4405e-04
# Epoch 133/500
# 0s - loss: 602.8615 - categorical_crossentropy: 602.8615 - acc: 0.0055
# Epoch 134/500
# 0s - loss: 602.7336 - categorical_crossentropy: 602.7336 - acc: 4.9603e-04
# Epoch 135/500
# 0s - loss: 602.8108 - categorical_crossentropy: 602.8109 - acc: 0.0022
# Epoch 136/500
# 0s - loss: 602.6547 - categorical_crossentropy: 602.6547 - acc: 4.9603e-04
# Epoch 137/500
# 0s - loss: 602.4412 - categorical_crossentropy: 602.4412 - acc: 0.0022
# Epoch 138/500
# 0s - loss: 602.6458 - categorical_crossentropy: 602.6457 - acc: 0.0017
# Epoch 139/500
# 0s - loss: 602.8059 - categorical_crossentropy: 602.8058 - acc: 0.0012
# Epoch 140/500
# 0s - loss: 603.7371 - categorical_crossentropy: 603.7371 - acc: 0.0047
# Epoch 141/500
# 0s - loss: 602.9475 - categorical_crossentropy: 602.9475 - acc: 9.9206e-04
# Epoch 142/500
# 0s - loss: 602.4244 - categorical_crossentropy: 602.4243 - acc: 0.0017
# Epoch 143/500
# 0s - loss: 602.1736 - categorical_crossentropy: 602.1737 - acc: 7.4405e-04
# Epoch 144/500
# 0s - loss: 602.1804 - categorical_crossentropy: 602.1804 - acc: 0.0017
# Epoch 145/500
# 0s - loss: 602.0737 - categorical_crossentropy: 602.0737 - acc: 7.4405e-04
# Epoch 146/500
# 0s - loss: 602.2373 - categorical_crossentropy: 602.2373 - acc: 0.0022
# Epoch 147/500
# 0s - loss: 602.1431 - categorical_crossentropy: 602.1431 - acc: 2.4802e-04
# Epoch 148/500
# 0s - loss: 602.3053 - categorical_crossentropy: 602.3053 - acc: 4.9603e-04
# Epoch 149/500
# 0s - loss: 602.1332 - categorical_crossentropy: 602.1332 - acc: 0.0017
# Epoch 150/500
# 0s - loss: 602.3528 - categorical_crossentropy: 602.3528 - acc: 0.0035
# Epoch 151/500
# 0s - loss: 602.4453 - categorical_crossentropy: 602.4453 - acc: 7.4405e-04
# Epoch 152/500
# 0s - loss: 602.6669 - categorical_crossentropy: 602.6669 - acc: 0.0035
# Epoch 153/500
# 0s - loss: 602.9024 - categorical_crossentropy: 602.9024 - acc: 9.9206e-04
# Epoch 154/500
# 0s - loss: 602.5728 - categorical_crossentropy: 602.5728 - acc: 0.0020
# Epoch 155/500
# 0s - loss: 602.3268 - categorical_crossentropy: 602.3267 - acc: 0.0000e+00
# Epoch 156/500
# 0s - loss: 602.1628 - categorical_crossentropy: 602.1629 - acc: 4.9603e-04
# Epoch 157/500
# 0s - loss: 602.2029 - categorical_crossentropy: 602.2029 - acc: 4.9603e-04
# Epoch 158/500
# 0s - loss: 602.1191 - categorical_crossentropy: 602.1191 - acc: 0.0015
# Epoch 159/500
# 0s - loss: 602.5244 - categorical_crossentropy: 602.5244 - acc: 0.0015
# Epoch 160/500
# 0s - loss: 602.3559 - categorical_crossentropy: 602.3560 - acc: 9.9206e-04
# Epoch 161/500
# 0s - loss: 602.5483 - categorical_crossentropy: 602.5483 - acc: 0.0022
# Epoch 162/500
# 0s - loss: 602.2437 - categorical_crossentropy: 602.2437 - acc: 7.4405e-04
# Epoch 163/500
# 0s - loss: 602.0928 - categorical_crossentropy: 602.0928 - acc: 4.9603e-04
# Epoch 164/500
# 0s - loss: 602.1463 - categorical_crossentropy: 602.1463 - acc: 0.0012
# Epoch 165/500
# 0s - loss: 602.1313 - categorical_crossentropy: 602.1313 - acc: 0.0012
# Epoch 166/500
# 0s - loss: 602.1353 - categorical_crossentropy: 602.1352 - acc: 4.9603e-04
# Epoch 167/500
# 0s - loss: 602.3218 - categorical_crossentropy: 602.3218 - acc: 0.0037
# Epoch 168/500
# 0s - loss: 602.3646 - categorical_crossentropy: 602.3646 - acc: 2.4802e-04
# Epoch 169/500
# 0s - loss: 602.6180 - categorical_crossentropy: 602.6180 - acc: 2.4802e-04
# Epoch 170/500
# 0s - loss: 602.3523 - categorical_crossentropy: 602.3523 - acc: 4.9603e-04
# Epoch 171/500
# 0s - loss: 602.1384 - categorical_crossentropy: 602.1384 - acc: 0.0000e+00
# Epoch 172/500
# 0s - loss: 602.2117 - categorical_crossentropy: 602.2117 - acc: 0.0017
# Epoch 173/500
# 0s - loss: 602.2024 - categorical_crossentropy: 602.2024 - acc: 9.9206e-04
# Epoch 174/500
# 0s - loss: 602.0743 - categorical_crossentropy: 602.0745 - acc: 0.0012
# Epoch 175/500
# 0s - loss: 602.1631 - categorical_crossentropy: 602.1630 - acc: 9.9206e-04
# Epoch 176/500
# 0s - loss: 602.6255 - categorical_crossentropy: 602.6255 - acc: 0.0022
# Epoch 177/500
# 0s - loss: 602.2470 - categorical_crossentropy: 602.2469 - acc: 4.9603e-04
# Epoch 178/500
# 0s - loss: 602.0760 - categorical_crossentropy: 602.0760 - acc: 4.9603e-04
# Epoch 179/500
# 0s - loss: 601.8817 - categorical_crossentropy: 601.8817 - acc: 0.0012
# Epoch 180/500
# 0s - loss: 601.8885 - categorical_crossentropy: 601.8885 - acc: 4.9603e-04
# Epoch 181/500
# 0s - loss: 601.8462 - categorical_crossentropy: 601.8463 - acc: 0.0017
# Epoch 182/500
# 0s - loss: 601.8143 - categorical_crossentropy: 601.8143 - acc: 4.9603e-04
# Epoch 183/500
# 0s - loss: 601.9796 - categorical_crossentropy: 601.9795 - acc: 7.4405e-04
# Epoch 184/500
# 0s - loss: 602.2050 - categorical_crossentropy: 602.2050 - acc: 0.0012
# Epoch 185/500
# 0s - loss: 601.9801 - categorical_crossentropy: 601.9801 - acc: 0.0000e+00
# Epoch 186/500
# 0s - loss: 602.0538 - categorical_crossentropy: 602.0538 - acc: 9.9206e-04
# Epoch 187/500
# 0s - loss: 602.3649 - categorical_crossentropy: 602.3649 - acc: 0.0022
# Epoch 188/500
# 0s - loss: 603.5967 - categorical_crossentropy: 603.5967 - acc: 0.0020
# Epoch 189/500
# 0s - loss: 602.6368 - categorical_crossentropy: 602.6369 - acc: 2.4802e-04
# Epoch 190/500
# 0s - loss: 602.1757 - categorical_crossentropy: 602.1757 - acc: 4.9603e-04
# Epoch 191/500
# 0s - loss: 602.3340 - categorical_crossentropy: 602.3340 - acc: 0.0022
# Epoch 192/500
# 0s - loss: 602.3518 - categorical_crossentropy: 602.3518 - acc: 7.4405e-04
# Epoch 193/500
# 0s - loss: 602.3921 - categorical_crossentropy: 602.3921 - acc: 0.0012
# Epoch 194/500
# 0s - loss: 602.0439 - categorical_crossentropy: 602.0441 - acc: 2.4802e-04
# Epoch 195/500
# 0s - loss: 602.0438 - categorical_crossentropy: 602.0438 - acc: 0.0000e+00
# Epoch 196/500
# 0s - loss: 602.0098 - categorical_crossentropy: 602.0098 - acc: 2.4802e-04
# Epoch 197/500
# 0s - loss: 601.8744 - categorical_crossentropy: 601.8744 - acc: 7.4405e-04
# Epoch 198/500
# 0s - loss: 601.8615 - categorical_crossentropy: 601.8615 - acc: 7.4405e-04
# Epoch 199/500
# 0s - loss: 601.9294 - categorical_crossentropy: 601.9294 - acc: 9.9206e-04
# Epoch 200/500
# 0s - loss: 601.9012 - categorical_crossentropy: 601.9012 - acc: 9.9206e-04
# Epoch 201/500
# 0s - loss: 602.0908 - categorical_crossentropy: 602.0908 - acc: 4.9603e-04
# Epoch 202/500
# 0s - loss: 601.8381 - categorical_crossentropy: 601.8381 - acc: 4.9603e-04
# Epoch 203/500
# 0s - loss: 601.8237 - categorical_crossentropy: 601.8237 - acc: 9.9206e-04
# Epoch 204/500
# 0s - loss: 601.8288 - categorical_crossentropy: 601.8289 - acc: 9.9206e-04
# Epoch 205/500
# 0s - loss: 601.7997 - categorical_crossentropy: 601.7997 - acc: 7.4405e-04
# Epoch 206/500
# 0s - loss: 602.0453 - categorical_crossentropy: 602.0453 - acc: 2.4802e-04
# Epoch 207/500
# 0s - loss: 602.0099 - categorical_crossentropy: 602.0099 - acc: 9.9206e-04
# Epoch 208/500
# 0s - loss: 603.3250 - categorical_crossentropy: 603.3250 - acc: 7.4405e-04
# Epoch 209/500
# 0s - loss: 602.7821 - categorical_crossentropy: 602.7820 - acc: 4.9603e-04
# Epoch 210/500
# 0s - loss: 602.7338 - categorical_crossentropy: 602.7338 - acc: 4.9603e-04
# Epoch 211/500
# 0s - loss: 602.5486 - categorical_crossentropy: 602.5486 - acc: 9.9206e-04
# Epoch 212/500
# 0s - loss: 602.1453 - categorical_crossentropy: 602.1453 - acc: 0.0012
# Epoch 213/500
# 0s - loss: 602.0157 - categorical_crossentropy: 602.0157 - acc: 0.0012
# Epoch 214/500
# 0s - loss: 601.9198 - categorical_crossentropy: 601.9197 - acc: 0.0012
# Epoch 215/500
# 0s - loss: 601.8347 - categorical_crossentropy: 601.8347 - acc: 9.9206e-04
# Epoch 216/500
# 0s - loss: 601.8512 - categorical_crossentropy: 601.8511 - acc: 7.4405e-04
# Epoch 217/500
# 0s - loss: 602.0735 - categorical_crossentropy: 602.0735 - acc: 0.0012
# Epoch 218/500

# %%
# Get image data w/ nibabel
import nibabel as nib
def get_data(filename):
    img = nib.load(filename)
    return img.get_data()
def scale(array):
    return (array-np.min(array))/(np.max(array) - np.min(array))    
mri_data = scale(get_data('../data/case_001_2.nii.gz')).transpose((2,0,1))
labelled_data = get_data('../data/case_001_labels.nii.gz').transpose((2,0,1))

# %%
from scipy.misc import imresize

def preprocess(mri_slice,tile=True):
    img0 = imresize(mri_slice, (224,224))
    img0.resize((img0.shape[0],img0.shape[1],1))
    if tile: img0 = np.tile(img0,3)
    img0 = img0.transpose((2,0,1))
    return np.expand_dims(img0, axis=0)
def preprocess_label(labels):
    labels = imresize(labels, (224,224))
    pos = np.where(labels==1)
    new_labels = np.zeros([labels.shape[0],labels.shape[1],2])
    new_labels[:,:,0] = 1
    new_labels[pos[0],pos[1],0] = 0
    new_labels[pos[0],pos[1],1] = 1
    new_labels = new_labels.transpose((2,0,1))
    return np.expand_dims(new_labels, axis=0)

# %%
dice_coef(y_train[0],y_train[0])
# Out:
# <tf.Tensor 'truediv_21:0' shape=() dtype=float64>

# %%
label_sums = labelled_data.sum(axis=(1,2))
x_train_arr = []
y_train_arr = [] 
#for mri_slice, labels in zip(mri_data, labelled_data):
for mri_slice, labels in zip(mri_data[np.where(label_sums>0)], labelled_data[np.where(label_sums>0)]):
    x_train_arr.append(preprocess(mri_slice))
    y_train_arr.append(preprocess_label(labels))
x_train = np.vstack(x_train_arr)
y_train = np.vstack(y_train_arr)

# %%
np.histogram(img,bins=20)

# %%
#img= model.predict(preprocess(mri_data[24])).squeeze()

#img[np.argmax(img, axis=0)]
pos = np.where(np.argmax(img, axis=0)>0)
img0 = np.zeros((img.shape[1],img.shape[2]))
img0[pos[0],pos[1]] = 1

# %%
# Out:
# 0.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

predict_slide = 21
img= model.predict(preprocess(mri_data[predict_slide])).squeeze()
pos = np.where(np.argmax(img, axis=0)>0)
img1 = np.zeros((img.shape[1],img.shape[2]))
img1[pos[0],pos[1]] = 1
fig, ax = plt.subplots(1,1)
#img1 = np.copy(img)
#img1[img<1] = 0
#ax.imshow(new_data)
#ax.imshow(imresize(mri_data[predict_slide], (224,224)),cmap=plt.cm.gray)
ax.imshow(np.ma.masked_where(img1<1, img1),alpha=.7,cmap=plt.cm.autumn, interpolation='none')
#plt.imshow(img1)
#actual = imresize(mri_data[predict_slide], (224,224))

#ax.imshow(np.ma.masked_where(actual==0, actual),alpha=.5,cmap=plt.cm.autumn, interpolation='none')
#plt.imshow(np.squeeze(img))

# %%
img  
np.where((img>.5))[0]

# %%
plt.imshow(preprocess(labelled_data[22], False).squeeze())
#plt.imshow(labelled_data[22])
labelled_data[20].sum()

# %%
label_sums = labelled_data.sum(axis=(1,2))
train_data = mri_data[np.where(label_sums==1)]
for i in range(0, mri_data.shape[2]):
    if skip_empty_slices:
        if np.sum(labelled_data[:,:,i]) == 0: continue
    train.append[i]
md = imresize(mri_data.transpose((2,0,1)), (33,224,224))
md.shape

# %%
# Get image data w/ nibabel
import nibabel as nib
def get_data(filename):
    img = nib.load(filename)
    return img.get_data()
def scale(array):
    return (array-np.min(array))/(np.max(array) - np.min(array))
mri_data = scale(get_data('../data/case_001_2.nii.gz'))
# Generate input to model (shape=(1,3,224,224))
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.misc import imresize
#plt.tight_layout()
img0 = imresize(mri_data[:,:,24], (224,224))
img = plt.imshow(img0) 

img0.resize((img0.shape[0],img0.shape[1],1))
img0_rgb = np.tile(img0,3)
img0_rgb = img0_rgb.transpose((2,0,1))
img0_rgb = np.expand_dims(img0_rgb, axis=0)
img0_rgb.shape

# %%
print(model.summary())

# %%
from keras.models import Model

def get_intermediate(layer_name,inp):
    intermediate_layer_model = Model(inputs=model.input,
                                     outputs=model.get_layer(layer_name).output)
    return np.squeeze(intermediate_layer_model.predict(inp))
import math
def show_range(data, plot_range):
    #plot_range = range(0,derp.shape[0],10)
    i = 0
    
    f, axarr = plt.subplots(math.ceil(len(plot_range)/3), 3)
    f.set_size_inches([10,10])
    for i in range(len(plot_range)):
        if len(axarr.shape)==1:
            ax = axarr[i]
        else:
            ax = axarr[int(i/3),i%3]
        ax.imshow(data[plot_range[i]])
        ax.set_title("Node %d"%plot_range[i])
    plt.show()

# %%
layer_name = 'conv2d_2'
out_conv2d_2 = get_intermediate(layer_name,img0_rgb)
show_range(out_conv2d_2, range(1,out_conv2d_2.shape[0],10))

# %%
import keras
keras.backend.image_data_format()
